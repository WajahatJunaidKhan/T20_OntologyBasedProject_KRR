# %%
import pandas as pd
import matplotlib.pyplot as plt
from rdflib import Graph, Literal, Namespace, RDF, URIRef
from rdflib.namespace import XSD
from rdflib import Graph

# %%
innings1_df = pd.read_csv(r'C:\Users\fgfhf\Desktop\KRR PROJECT\P9 - T20 Ontology based Analytics\Raw data\1st Innings T20.csv')

# %%
innings1_df.head(5)
# Out:
#    Unnamed: 0 matchId  balls  runs tossWinner  battingTeam bowlingTeam  \
# 0           0     5_1    0.1     0      India  West Indies       India
# 1           1     5_1    0.2     0      India  West Indies       India
# 2           2     5_1    0.3     0      India  West Indies       India
# 3           3     5_1    0.4     1      India  West Indies       India
# 4           4     5_1    0.5     0      India  West Indies       India
#
#    player_out        city                                              venue
# 0           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 1           1  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 2           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 3           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 4           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground

# %%
innings1_df.dtypes
# Out:
# Unnamed: 0       int64
# matchId         object
# balls          float64
# runs             int64
# tossWinner      object
# battingTeam     object
# bowlingTeam     object
# player_out       int64
# city            object
# venue           object
# dtype: object

# %%
innings2_df = pd.read_csv(r'C:\Users\fgfhf\Desktop\KRR PROJECT\P9 - T20 Ontology based Analytics\Raw data\2nd Innings T20.csv')

# %%
innings2_df.head(5)
# Out:
#    Unnamed: 0 matchId  balls  runs tossWinner battingTeam  bowlingTeam  \
# 0           0     5_2    0.1     0      India       India  West Indies
# 1           1     5_2    0.2     0      India       India  West Indies
# 2           2     5_2    0.3     1      India       India  West Indies
# 3           3     5_2    0.4     1      India       India  West Indies
# 4           4     5_2    0.5     0      India       India  West Indies
#
#    player_out        city                                              venue
# 0           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 1           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 2           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 3           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground
# 4           0  Lauderhill  Central Broward Regional Park Stadium Turf Ground

# %%
# Plotting the distribution of runs scored
plt.figure(figsize=(8, 6))
plt.hist(innings1_df['runs'], bins=20, color='skyblue')
plt.xlabel('Runs Scored')
plt.ylabel('Frequency')
plt.title('Distribution of Runs Scored Innings 1')
plt.show()

# %%
# Plotting the distribution of runs scored
plt.figure(figsize=(8, 6))
plt.hist(innings2_df['runs'], bins=20, color='skyblue')
plt.xlabel('Runs Scored')
plt.ylabel('Frequency')
plt.title('Distribution of Runs Scored Innings 2')
plt.show()

# %%
# Comparing runs scored by different teams from innings 1
plt.figure(figsize=(10, 6))
innings1_df.boxplot(column='runs', by='battingTeam', grid=False)
plt.xticks(rotation=45)
plt.xlabel('Batting Team')
plt.ylabel('Runs Scored')
plt.title('')
plt.show()

# %%
# Comparing runs scored by different teams from innings 2
plt.figure(figsize=(10, 6))
innings2_df.boxplot(column='runs', by='battingTeam', grid=False)
plt.xticks(rotation=45)
plt.xlabel('Batting Team')
plt.ylabel('Runs Scored')
plt.title('')
plt.show()

# %%
# Analyzing innings 1
plt.figure(figsize=(8, 6))
plt.hist(innings1_df['balls'], bins=20, color='lightgreen')
plt.xlabel('Balls Played')
plt.ylabel('Frequency')
plt.title('Distribution of Balls Played')
plt.show()

# %%
# Analyzing innings 2
plt.figure(figsize=(8, 6))
plt.hist(innings2_df['balls'], bins=20, color='lightgreen')
plt.xlabel('Balls Played')
plt.ylabel('Frequency')
plt.title('Distribution of Balls Played')
plt.show()

# %%
# Visualizing match venues
venue_counts = innings1_df['venue'].value_counts().head(10)
venue_counts.plot(kind='bar', color='orange', figsize=(10, 6))
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.title('Top 10 Venues by Number of Matches of innings 1')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualizing match venues
venue_counts = innings2_df['venue'].value_counts().head(10)
venue_counts.plot(kind='bar', color='orange', figsize=(10, 6))
plt.xlabel('Venue')
plt.ylabel('Number of Matches')
plt.title('Top 10 Venues by Number of Matches of innings 2')
plt.xticks(rotation=45)
plt.show()

# %%
# Correlation matrix
correlation_matrix = innings1_df.corr()
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title('Correlation Matrix of innings 1')
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.show()

# %%
# Correlation matrix
correlation_matrix = innings2_df.corr()
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title('Correlation Matrix of innings 2')
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.show()

# %%
relevant_columns_innings1 = ['matchId', 'balls', 'runs', 'tossWinner', 'battingTeam', 'bowlingTeam', 'player_out', 'city', 'venue']
relevant_columns_innings2 = ['matchId', 'balls', 'runs', 'tossWinner', 'battingTeam', 'bowlingTeam', 'player_out', 'city', 'venue']

# %%
innings1_data = innings1_df[relevant_columns_innings1]
innings2_data = innings2_df[relevant_columns_innings2]

# %%
combined_innings_data = pd.concat([innings1_data, innings2_data], ignore_index=True)

# %%
# Correlation matrix
correlation_matrix = combined_innings_data.corr()
plt.figure(figsize=(8, 6))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title('Correlation Matrix')
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=45)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.show()

# %% [markdown]
# # Creating RDF file

# %%
from rdflib import Graph, Literal, Namespace, RDF, URIRef
from rdflib.namespace import XSD


# Create a namespace for your ontology
onto = Namespace("http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#")

# Instantiate a new RDF graph
g = Graph()

# Define namespaces
g.bind("owl", "http://www.w3.org/2002/07/owl#")
g.bind("xsd", "http://www.w3.org/2001/XMLSchema#")
g.bind("", onto)

# Function to generate RDF triples for each row of innings data
def create_rdf_triples(data, innings):
    for index, row in data.iterrows():
        match_id = row['matchId']
        balls = row['balls']
        runs = row['runs']
        toss_winner = row['tossWinner']
        batting_team = row['battingTeam']
        bowling_team = row['bowlingTeam']
        player_out = row['player_out']
        city = row['city']
        venue = row['venue']

        # Create unique URIs for match and innings
        match_uri = onto[f"Match_{innings}_{match_id}"]
        inning_uri = onto[f"{innings}_Innings_T20"]

        # Add triples to the graph
        g.add((match_uri, RDF.type, inning_uri))
        g.add((match_uri, onto.hasBalls, Literal(balls, datatype=XSD.float)))
        g.add((match_uri, onto.hasRuns, Literal(runs, datatype=XSD.int)))
        g.add((match_uri, onto.hasTossWinner, Literal(toss_winner)))
        g.add((match_uri, onto.hasBattingTeam, Literal(batting_team)))
        g.add((match_uri, onto.hasBowlingTeam, Literal(bowling_team)))
        g.add((match_uri, onto.hasPlayerOut, Literal(player_out, datatype=XSD.int)))
        g.add((match_uri, onto.hasCity, Literal(city)))
        g.add((match_uri, onto.hasVenue, Literal(venue)))
        
# Assuming you have parsed your data into pandas DataFrames
innings1_data = pd.read_csv(r'C:\Users\fgfhf\Desktop\KRR PROJECT\P9 - T20 Ontology based Analytics\Raw data\1st Innings T20.csv')
innings2_data = pd.read_csv(r'C:\Users\fgfhf\Desktop\KRR PROJECT\P9 - T20 Ontology based Analytics\Raw data\2nd Innings T20.csv')

# Create RDF triples for each innings
create_rdf_triples(innings1_data, "1st")
create_rdf_triples(innings2_data, "2nd")

# Serialize RDF graph to a file
g.serialize(destination='mapped_data.rdf', format='xml')

# %% [markdown]
# # Classes

# %%
g = Graph()
g.parse("mapped_data.rdf", format='xml')

# Get all classes
query_classes = """
SELECT DISTINCT ?class 
WHERE {
    # ?s a ?class .
    FILTER(isURI(?class))
}
"""
classes = g.query(query_classes)

print("Classes:")
for cls in classes:
    print(cls)
# Out:
# Classes:
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#2nd_Innings_T20'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#1st_Innings_T20'),)

# %% [markdown]
# # Relations

# %%
# Get all relations (properties)
query_relations = """
SELECT DISTINCT ?property 
WHERE {
    # ?s ?property ?o .
    FILTER(isURI(?property))
}
"""
relations = g.query(query_relations)

print("\nRelations (Properties):")
for rel in relations:
    print(rel)
# Out:
# Relations (Properties):
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasBalls'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasRuns'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasVenue'),)
# (rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasBowlingTeam'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasBattingTeam'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasPlayerOut'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasTossWinner'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasCity'),)

# %% [markdown]
# # Instances

# %%
# Get all instances
query_instances = """
SELECT DISTINCT ?instance
WHERE {
    # ?instance a ?s .
    FILTER(isURI(?instance))
}
"""
instances = g.query(query_instances)

print("\nInstances:")
for inst in instances:
    print(inst)
# Out:
# Instances:
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1740_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_656_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1235_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_431_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1665_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1690_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1693_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_957_2'),)
# ...

# %% [markdown]
# # QUERIES

# %% [markdown]
# # Team with total scores

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("C:\\Users\\fgfhf\\Desktop\\KRR PROJECT\\mapped_data.rdf", format='xml')

# Execute the SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>

SELECT ?team (SUM(?runs) as ?totalRuns)
WHERE {
  # ?match rdf:type onto:1st_Innings_T20 .  
  # ?match onto:hasBattingTeam ?team .
  # ?match onto:hasRuns ?runs .
}
GROUP BY ?team
"""
results = g.query(query)

# Check if any results are returned
if len(results) == 0:
    print("No results found.")
else:
    # Process and display/query results
    for row in results:
        print(row)
# Out:
# (rdflib.term.Literal('West Indies'), rdflib.term.Literal('1028', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.Literal('Zimbabwe'), rdflib.term.Literal('615', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.Literal('England'), rdflib.term.Literal('979', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.Literal('Pakistan'), rdflib.term.Literal('1364', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.Literal('South Africa'), rdflib.term.Literal('1307', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.Literal('Australia'), rdflib.term.Literal('1004', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# (rdflib.term.Literal('New Zealand'), rdflib.term.Literal('1222', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))
# ...

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("mapped_data.rdf", format='xml')

# Iterate through the first few triples to inspect the data
for index, (subject, predicate, obj) in enumerate(g):
    if index < 10:  # Change this number to inspect more triples
        print(f"Triple {index + 1}: Subject: {subject}, Predicate: {predicate}, Object: {obj}")
    else:
        break
# Out:
# Triple 1: Subject: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1740_2, Predicate: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasBalls, Object: 1.2
# Triple 2: Subject: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_656_2, Predicate: http://www.w3.org/1999/02/22-rdf-syntax-ns#type, Object: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#2nd_Innings_T20
# Triple 3: Subject: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1235_2, Predicate: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasBalls, Object: 12.4
# Triple 4: Subject: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_431_2, Predicate: http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#hasBalls, Object: 8.1
# ...

# %% [markdown]
# # Get all distinct teams present in the RDF data

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("C:\\Users\\fgfhf\\Desktop\\KRR PROJECT\\mapped_data.rdf", format='xml')

# Execute the SPARQL query
query = """
PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>

SELECT DISTINCT ?team
WHERE {
  # ?match onto:hasBattingTeam ?team .
}
"""
results = g.query(query)

# Check if any results are returned
if len(results) == 0:
    print("No results found.")
else:
    # Process and display/query results
    for row in results:
        print(row)
# Out:
# (rdflib.term.Literal('England'),)
# (rdflib.term.Literal('Sri Lanka'),)
# (rdflib.term.Literal('India'),)
# (rdflib.term.Literal('Australia'),)
# (rdflib.term.Literal('West Indies'),)
# (rdflib.term.Literal('Zimbabwe'),)
# (rdflib.term.Literal('New Zealand'),)
# (rdflib.term.Literal('Afghanistan'),)
# (rdflib.term.Literal('Pakistan'),)
# (rdflib.term.Literal('South Africa'),)
# (rdflib.term.Literal('Ireland'),)
# (rdflib.term.Literal('Bangladesh'),)
# (rdflib.term.Literal('Netherlands'),)

# %% [markdown]
# # Find matches played in a particular city

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("C:\\Users\\fgfhf\\Desktop\\KRR PROJECT\\mapped_data.rdf", format='xml')

# Execute the SPARQL query
query = """
PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>

SELECT ?match
WHERE {
  # ?match onto:hasCity "St Kitts" .
}

"""
results = g.query(query)

# Check if any results are returned
if len(results) == 0:
    print("No results found.")
else:
    # Process and display/query results
    for row in results:
        print(row)
# Out:
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1181_1'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1126_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1681_1'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_340_1'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1181_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1681_2'),)
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1169_1'),)
# ...

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("C:\\Users\\fgfhf\\Desktop\\KRR PROJECT\\mapped_data.rdf", format='xml')

# Execute the SPARQL query
query = """
PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>

SELECT ?match ?city
WHERE {
  VALUES ?match {
    <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1>
    <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1181_1>
    <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1126_2>
    <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1681_1>
  }
  # ?match onto:hasCity ?city .
}
"""
results = g.query(query)

# Check if any results are returned
if len(results) == 0:
    print("No results found.")
else:
    # Process and display/query results
    for row in results:
        print(row)
# Out:
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1'), rdflib.term.Literal('St Kitts'))
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1181_1'), rdflib.term.Literal('St Kitts'))
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_2nd_1126_2'), rdflib.term.Literal('St Kitts'))
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1681_1'), rdflib.term.Literal('St Kitts'))

# %% [markdown]
# # Specific Information for Matches in a City

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("C:\\Users\\fgfhf\\Desktop\\KRR PROJECT\\mapped_data.rdf", format='xml')

# Execute the SPARQL query
query = """
PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>

SELECT ?match ?team ?runs
WHERE {
  # ?match onto:hasCity "St Kitts" .
  # ?match onto:hasBattingTeam ?team .
  # ?match onto:hasRuns ?runs .
}
"""
results = g.query(query)

# Check if any results are returned
if len(results) == 0:
    print("No results found.")
else:
    # Process and display/query results
    for row in results:
        print(row)
# Out:
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1'), rdflib.term.Literal('Bangladesh'), rdflib.term.Literal('1', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int')))
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1'), rdflib.term.Literal('Bangladesh'), rdflib.term.Literal('4', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int')))
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1'), rdflib.term.Literal('Bangladesh'), rdflib.term.Literal('0', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int')))
# (rdflib.term.URIRef('http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#Match_1st_1126_1'), rdflib.term.Literal('Bangladesh'), rdflib.term.Literal('6', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#int')))
# ...

# %% [markdown]
# # Distinct Tosswinner

# %%
from rdflib import Graph

# Load your RDF data into a graph
g = Graph()
g.parse("mapped_data.rdf", format='xml')

# Execute the SPARQL query
query = """
PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>
SELECT DISTINCT ?tossWinner
WHERE {
  # ?match onto:hasTossWinner ?tossWinner .
}
"""
results = g.query(query)

# Check if any results are returned
if len(results) == 0:
    print("No results found.")
else:
    # Process and display/query results
    for row in results:
        print(row)
# Out:
# (rdflib.term.Literal('West Indies'),)
# (rdflib.term.Literal('Pakistan'),)
# (rdflib.term.Literal('India'),)
# (rdflib.term.Literal('Australia'),)
# (rdflib.term.Literal('England'),)
# (rdflib.term.Literal('New Zealand'),)
# (rdflib.term.Literal('South Africa'),)
# (rdflib.term.Literal('Afghanistan'),)
# (rdflib.term.Literal('Sri Lanka'),)
# (rdflib.term.Literal('Netherlands'),)
# (rdflib.term.Literal('Bangladesh'),)
# (rdflib.term.Literal('Ireland'),)
# (rdflib.term.Literal('nan', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#double')),)
# (rdflib.term.Literal('Zimbabwe'),)

# %% [markdown]
# # Player Performance

# %%
from rdflib import Graph, Namespace, RDF

# Load RDF file into the graph
g = Graph()
g.parse("mapped_data.rdf")

# Query to find the top run-scorers
query_top_run_scorers = """
    PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>
    SELECT ?player (SUM(?runs) AS ?total_runs)
    WHERE {
        # ?match onto:hasPlayerOut ?player_out .
        # ?match onto:hasRuns ?runs .
        FILTER(?player_out = 0)  # Assuming 0 denotes player not out
    }
    GROUP BY ?player
    ORDER BY DESC(?total_runs)
    LIMIT 10
"""

# Execute the query
result = g.query(query_top_run_scorers)

# Display top run-scorers
for row in result:
    print(f"Player: {row['player']} - Total Runs: {row['total_runs']}")
# Out:
# Player: None - Total Runs: 22847

# %% [markdown]
# # Average Runs by Player

# %%
query_avg_runs_by_player = """
    PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>
    SELECT ?player (AVG(?runs) AS ?avg_runs)
    WHERE {
        # ?match onto:hasPlayerOut ?player_out .
        # ?match onto:hasRuns ?runs .
        # ?match onto:hasBattingTeam ?team .
        # ?match onto:hasBowlingTeam ?opponent_team .
        # ?match onto:hasPlayerOut ?player .
    }
    GROUP BY ?player
    ORDER BY DESC(?avg_runs)
    LIMIT 10
"""

# Execute the query
result = g.query(query_avg_runs_by_player)

# Display average runs by player
for row in result:
    print(f"Player: {row['player']} - Average Runs: {row['avg_runs']}")
# Out:
# Player: 1 - Average Runs: 2.703916636722960833632770392
# Player: 0 - Average Runs: 2.703851419727364724090719686

# %% [markdown]
# # Team Performance

# %%
query_avg_runs_by_team = """
    PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>
    SELECT ?team (AVG(?runs) AS ?avg_runs)
    WHERE {
        # ?match onto:hasBattingTeam ?team .
        # ?match onto:hasRuns ?runs .
    }
    GROUP BY ?team
    ORDER BY DESC(?avg_runs)
"""

# Execute the query
result = g.query(query_avg_runs_by_team)

# Display average runs by team
for row in result:
    print(f"Team: {row['team']} - Average Runs: {row['avg_runs']}")
# Out:
# Team: Pakistan - Average Runs: 2.729989327641408751334044824
# Team: England - Average Runs: 2.719059405940594059405940594
# Team: Bangladesh - Average Runs: 2.716857610474631751227495908
# Team: West Indies - Average Runs: 2.710967741935483870967741935
# Team: India - Average Runs: 2.709158415841584158415841584
# Team: New Zealand - Average Runs: 2.707434052757793764988009592
# Team: Australia - Average Runs: 2.704861111111111111111111111
# Team: Afghanistan - Average Runs: 2.701639344262295081967213115
# Team: South Africa - Average Runs: 2.696296296296296296296296296
# Team: Sri Lanka - Average Runs: 2.690629011553273427471116816
# Team: Zimbabwe - Average Runs: 2.688340807174887892376681614
# Team: Netherlands - Average Runs: 2.647798742138364779874213836
# Team: Ireland - Average Runs: 2.621019108280254777070063694

# %% [markdown]
# # Venue Analysis

# %%
query_most_played_venues = """
    PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>
    SELECT ?venue (COUNT(?match) AS ?matches_played)
    WHERE {
        # ?match onto:hasVenue ?venue .
    }
    GROUP BY ?venue
    ORDER BY DESC(?matches_played)
    LIMIT 10
"""

# Execute the query
result = g.query(query_most_played_venues)

# Display venues with most matches played
for row in result:
    print(f"Venue: {row['venue']} - Matches Played: {row['matches_played']}")
# Out:
# Venue: Dubai International Cricket Stadium - Matches Played: 86
# Venue: Shere Bangla National Stadium - Matches Played: 60
# Venue: Harare Sports Club - Matches Played: 56
# Venue: R Premadasa Stadium - Matches Played: 51
# Venue: New Wanderers Stadium - Matches Played: 46
# Venue: Eden Park - Matches Played: 46
# Venue: Newlands - Matches Played: 42
# Venue: Pallekele International Cricket Stadium - Matches Played: 40
# Venue: Shere Bangla National Stadium, Mirpur - Matches Played: 36
# Venue: Kensington Oval, Bridgetown - Matches Played: 34

# %% [markdown]
# # Matches per City

# %%
query_matches_per_city = """
    PREFIX onto: <http://www.semanticweb.org/user/ontologies/2022/11/untitled-ontology-12#>
    SELECT ?city (COUNT(?match) AS ?matches_count)
    WHERE {
        # ?match onto:hasCity ?city .
    }
    GROUP BY ?city
    ORDER BY DESC(?matches_count)
"""

# Execute the query
result = g.query(query_matches_per_city)

# Display matches count per city
for row in result:
    print(f"City: {row['city']} - Matches Played: {row['matches_count']}")
# Out:
# City: Dubai - Matches Played: 86
# City: Colombo - Matches Played: 83
# City: Johannesburg - Matches Played: 58
# City: Mirpur - Matches Played: 58
# City: Harare - Matches Played: 56
# City: Abu Dhabi - Matches Played: 48
# City: Auckland - Matches Played: 48
# City: London - Matches Played: 43
# City: Cape Town - Matches Played: 42
# City: Dhaka - Matches Played: 38
# City: Barbados - Matches Played: 34
# City: Pallekele - Matches Played: 34
# City: Wellington - Matches Played: 30
# City: Sharjah - Matches Played: 28
# City: Sydney - Matches Played: 26
# City: Durban - Matches Played: 26
# City: Melbourne - Matches Played: 25
# City: Centurion - Matches Played: 24
# City: St Lucia - Matches Played: 24
# City: Hamilton - Matches Played: 24
# City: Nottingham - Matches Played: 24
# City: Lahore - Matches Played: 22
# City: Chittagong - Matches Played: 22
# City: Manchester - Matches Played: 21
# City: Lauderhill - Matches Played: 20
# City: Southampton - Matches Played: 18
# ...
